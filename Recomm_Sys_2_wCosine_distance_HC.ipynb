# %%
'''
# Spotify  provides wide range of fatures about songs such as : Popularity, 
 Explicit, Danceability, Energy, Key, Loudness, Mode, Speechiness,
 Acousticness, Instrumentalness, Liveness, Valence,Tempo

Most of these features are already numeric or with a little bit of data
manipulation they can be converted into numeric data. Numeric features
allows calculating cosine similarity between songs. I found the cosine
distance between songs and offered a recommendation system based on
cosine distance. 
'''
# Out:
# '\n# Spotify  provides wide range of fatures about songs such as : Popularity, \n Explicit, Danceability, Energy, Key, Loudness, Mode, Speechiness,\n Acousticness, Instrumentalness, Liveness, Valence,Tempo\n\nMost of these features are already numeric or with a little bit of data\nmanipulation they can be converted into numeric data. Numeric features\nallows calculating cosine similarity between songs. I found the cosine\ndistance between songs and offered a recommendation system based on\ncosine distance. \n'

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("music_data.csv")

# %%
df.drop(['Unnamed: 0','Album ID', 'Track ID', 'External URLs','Release Date','Duration (ms)'], axis =1 , inplace=True)

# %%
df.T
# Out:
#                               0             1           2            3     \
# Track Name        ...Ready For It?  Life Changes   24K Magic  Galway Girl
# Artists               Taylor Swift  Thomas Rhett  Bruno Mars   Ed Sheeran
# Album Name        ...Ready For It?  Life Changes   24K Magic   ÷ (Deluxe)
# Popularity                       0            63          81           80
# Explicit                     False         False       False        False
# Danceability                 0.615         0.687       0.818        0.624
# Energy                       0.779         0.845       0.803        0.876
# Key                              2             7           1            9
# Loudness                    -6.454         -4.37      -4.282       -3.374
# Mode                             1             1           1            1
# Speechiness                  0.135        0.0576      0.0797          0.1
# Acousticness                0.0665           0.1       0.034       0.0735
# ...

# %%
df['Track Name']
# Out:
# 0               ...Ready For It?
# 1                   Life Changes
# 2                      24K Magic
# 3                    Galway Girl
# 4                     Photograph
#                   ...
# 2995                 The Spectre
# 2996                     Happier
# 2997              Drew Barrymore
# 2998             Let You Love Me
# 2999    No Stylist (feat. Drake)
# Name: Track Name, Length: 3000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Name        3000 non-null   object
#  1   Artists           3000 non-null   object
#  2   Album Name        3000 non-null   object
#  3   Popularity        3000 non-null   int64
#  4   Explicit          3000 non-null   bool
#  5   Danceability      3000 non-null   float64
#  6   Energy            3000 non-null   float64
#  7   Key               3000 non-null   int64
#  8   Loudness          3000 non-null   float64
#  9   Mode              3000 non-null   int64
#  10  Speechiness       3000 non-null   float64
#  11  Acousticness      3000 non-null   float64
#  12  Instrumentalness  3000 non-null   float64
#  13  Liveness          3000 non-null   float64
#  14  Valence           3000 non-null   float64
#  15  Tempo             3000 non-null   float64
# ...

# %%
df['Explicit'].replace({True: 1, False: 0}, inplace = True)

# %%
df.columns
# Out:
# Index(['Track Name', 'Artists', 'Album Name', 'Popularity', 'Explicit',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo'],
#       dtype='object')

# %%
df_c = df[['Popularity','Explicit', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode',\
       'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',\
       'Valence', 'Tempo']]
similarity = cosine_similarity(df_c)

# %%
similarity[0]
# Out:
# array([1.        , 0.81238166, 0.79748773, ..., 0.92257824, 0.84182571,
#        0.91906714])

# %%
similarity[1]
# Out:
# array([0.81238166, 1.        , 0.99797394, ..., 0.97406884, 0.99809291,
#        0.9759988 ])

# %%
# DEVELOP  a RECOMMENDATION FUNCTION

# %%
df[df['Track Name'].str.contains('Life Changes')]
# Out:
#      Track Name       Artists    Album Name  Popularity  Explicit  \
# 1  Life Changes  Thomas Rhett  Life Changes          63         0
#
#    Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 1         0.687   0.845    7     -4.37     1       0.0576           0.1
#
#    Instrumentalness  Liveness  Valence   Tempo
# 1               0.0    0.0452    0.809  87.972

# %%
sorted(similarity[0])
# Out:
# [0.5437634406340017,
#  0.5938512725688608,
#  0.6174191921450805,
#  0.633807745443271,
#  0.6662887098244455,
#  0.6747011032951017,
#  0.6780608480573813,
#  0.6790536745550784,
#  0.6857848668921721,
#  0.6889365178129004,
#  0.6916849593941351,
#  0.6918902052428311,
#  0.692039312122102,
#  0.6920987930810997,
#  0.6925711074311164,
#  0.6934115925643795,
#  0.693866304097474,
#  0.6940261585175751,
#  0.6959782824921027,
#  0.6982508930873106,
#  0.6983742412715883,
#  0.6989098284994677,
#  0.7028363533246139,
#  0.7034831187326852,
#  0.7039793708346929,
#  0.7066481017290817,
#  0.7072001144687015,
#  0.707576714679486,
#  0.7077104741239991,
#  0.7118363158528066,
#  0.7131326668453967,
#  0.715021275899647,
#  0.7155612139382024,
#  0.7160385913959931,
#  0.7163658440014716,
#  0.7163718400302149,
#  0.7176888183374036,
#  0.7183551946034472,
#  0.7186236151311678,
#  0.7189786836777403,
#  0.7202667753050097,
#  0.7205420902794535,
#  0.7206098866582933,
# ...

# %%
df[df['Track Name'].str.contains('Life Changes') ].index[0]
# Out:
# 1

# %%
sorted(similarity[1])
# Out:
# [0.7869557858816544,
#  0.7889016828963286,
#  0.7909764129236801,
#  0.7946561176310438,
#  0.7946561176310438,
#  0.7948224576953955,
#  0.7949775447219204,
#  0.7951268234741952,
#  0.79704235265146,
#  0.8013129724561973,
#  0.801419558255551,
#  0.803045859567312,
#  0.8041597223436913,
#  0.805383063224943,
#  0.8054615484212385,
#  0.8056193872953976,
#  0.8059870432713453,
#  0.8064412285022772,
#  0.8068932310438278,
#  0.8068940758323246,
#  0.8075247934928427,
#  0.8084152030629024,
#  0.8084574983637998,
#  0.808731024052901,
#  0.8090352857933751,
#  0.8092805039993792,
#  0.8093480920869429,
#  0.8093919820083945,
#  0.8094123834516337,
#  0.8094217866033905,
#  0.8095557337507627,
#  0.8097623015407818,
#  0.8098979988043358,
#  0.8099225590688177,
#  0.8099918996956014,
#  0.8100677727863724,
#  0.8102775658952016,
#  0.8103040202214808,
#  0.8104667281846551,
#  0.8105308554302857,
#  0.8105691925019687,
#  0.8105796703846452,
#  0.810598846470232,
# ...

# %%
for count, value in enumerate(similarity[1]):
    print(count,value)
# Out:
# 0 0.8123816602300833
# 1 0.9999999999999999
# 2 0.9979739390044499
# 3 0.9984559211951851
# 4 0.9974038155963367
# 5 0.8195824998427351
# 6 0.9628919174952925
# 7 0.993800318350474
# 8 0.8141603962441215
# 9 0.9800070587892539
# 10 0.955914671762006
# 11 0.9998750570272745
# 12 0.9784608665495602
# 13 0.9973152883883832
# 14 0.9975086731752291
# 15 0.998025452159256
# 16 0.9974704881435622
# 17 0.9974172223358517
# 18 0.9821322140051829
# 19 0.8212573383080309
# 20 0.9914823506448318
# 21 0.9944772402217722
# 22 0.8195857875633873
# 23 0.9834317057233267
# 24 0.9869110528841174
# 25 0.991932064141082
# 26 0.9977414747530357
# 27 0.8122779891302654
# 28 0.9829661581798699
# 29 0.9941472066838319
# 30 0.9972758607670265
# 31 0.9902559352010329
# 32 0.9977195748069955
# 33 0.9960488997324538
# 34 0.9945469420247993
# 35 0.972852871208499
# 36 0.9682620835785477
# 37 0.9923019370391694
# 38 0.8187707616630072
# 39 0.9964102984935613
# 40 0.9991633330155227
# 41 0.9978834118745464
# ...

# %%
list(enumerate(similarity[0]))
# Out:
# [(0, 1.0),
#  (1, 0.8123816602300833),
#  (2, 0.797487725860262),
#  (3, 0.7797640588351689),
#  (4, 0.7824039207281387),
#  (5, 0.998468464700058),
#  (6, 0.633807745443271),
#  (7, 0.8542327676262609),
#  (8, 0.9981094146204342),
#  (9, 0.6857848668921721),
#  (10, 0.9473562336755463),
#  (11, 0.8104645465433526),
#  (12, 0.9148890396979156),
#  (13, 0.7694304152388673),
#  (14, 0.8473215267172186),
#  (15, 0.8261191439826904),
#  (16, 0.786585615031543),
#  (17, 0.8361674345890328),
#  (18, 0.6889365178129004),
#  (19, 0.9970099734143774),
#  (20, 0.8812182913569546),
#  (21, 0.8609444825516638),
#  (22, 0.9989672849156521),
#  (23, 0.9013150973356473),
#  (24, 0.7206098866582933),
#  (25, 0.8779928830465452),
#  (26, 0.791994327412387),
#  (27, 0.9999354340162128),
#  (28, 0.6989098284994677),
#  (29, 0.7450039090734205),
#  (30, 0.8334928939846671),
#  (31, 0.8844489996953726),
#  (32, 0.8044338303735219),
#  (33, 0.7606680359535731),
#  (34, 0.8672992074257712),
# ...

# %%
sorted(list(enumerate(similarity[1])),reverse = True,   key = lambda x:x[1])
# Out:
# [(1, 0.9999999999999999),
#  (337, 0.9999531997040464),
#  (1531, 0.9999476450636043),
#  (1530, 0.9999449815280266),
#  (1706, 0.9999374931902425),
#  (316, 0.9999107275827417),
#  (341, 0.999894414130292),
#  (1353, 0.999890434551337),
#  (11, 0.9998750570272745),
#  (1412, 0.9998692659435001),
#  (53, 0.9998624445505977),
#  (732, 0.9998491807729835),
#  (562, 0.9998254867466106),
#  (1481, 0.9998098667108946),
#  (759, 0.999805845338927),
#  (86, 0.9998031732925798),
#  (1521, 0.9998014437909727),
#  (510, 0.9997833068852117),
#  (1868, 0.9997821881774864),
#  (762, 0.9997602695475508),
#  (455, 0.9997564390814595),
#  (1048, 0.9997474653425628),
#  (581, 0.9997444994500034),
#  (48, 0.9997404333225297),
#  (630, 0.9997338612678522),
#  (644, 0.9997210884296578),
#  (92, 0.9997176013148491),
#  (1492, 0.9997102955779598),
#  (2811, 0.9997089101906297),
#  (2353, 0.9997063531972656),
#  (112, 0.9997013032967825),
#  (682, 0.9996961425265043),
#  (1356, 0.9996875051146681),
# ...

# %%
def recommend_track(track_name) :
    track_list = df[df['Track Name'].str.contains(track_name)]
    #print(track_list)
    if len(track_list):
        track_idx = track_list.index[0]
        indexes = sorted(list(enumerate(similarity[track_idx])),reverse = True,   key = lambda x:x[1])[1:11]

        for i in indexes :
            track_indx, similarity_val = i;
            print("similarity: {} \t  {}".format(similarity_val, df['Track Name'].iloc[track_indx]) )
    else:
        return ('no tracks found in database')

# %%
recommend_track('Life Changes')
# Out:
# similarity: 0.9999531997040464 	  House Party
# similarity: 0.9999476450636043 	  Santa Monica
# similarity: 0.9999449815280266 	  Absolutely (Story of a Girl) - Radio Mix
# similarity: 0.9999374931902425 	  Saturday Sun
# similarity: 0.9999107275827417 	  Drinkin' Problem
# similarity: 0.999894414130292 	  Head Over Boots
# similarity: 0.999890434551337 	  Butterfly
# similarity: 0.9998750570272745 	  We Are Never Ever Getting Back Together
# similarity: 0.9998692659435001 	  Unpretty
# similarity: 0.9998624445505977 	  All of Me
